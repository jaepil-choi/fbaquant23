# %% [markdown]
# # HW01

# %% [markdown]
# 최재필

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Problem 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 6
#
# ![image.png](attachment:image.png)
