# %% [markdown]
# # HW03
#
# 최재필
#
# https://nbviewer.org/github/jaepil-choi/fbaquant23/blob/master/c1.1fe/hw/c1.1fe_hw03.ipynb

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path
from tqdm import tqdm

# %%
np.random.seed(123)

# %%
BASE_PATH = Path('.').resolve().parents[0]
BASE_PATH
# Out:
# WindowsPath('E:/VSCodeProjects/fbaquant23/c1.1fe')

# %%
# data_path = Path(__file__).resolve() / 'data' # Interactive shell에선 안된다. 
data_path = Path('.').resolve() / 'data'
data_path
# Out:
# WindowsPath('E:/VSCodeProjects/fbaquant23/c1.1fe/hw/data')

# %%
# coursera_data_path = BASE_PATH / 'coursera' / 'Introduction to Portfolio Construction and Analysis with Python' / 'data'
# coursera_data_path

# %% [markdown]
# ## Problem 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (a)

# %% [markdown]
# ### (b)

# %% [markdown]
# ### (c)

# %% [markdown]
# ### (d)

# %% [markdown]
# ### (e)

# %% [markdown]
# ## Problem 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (a)

# %% [markdown]
# ### (b)

# %% [markdown]
# ## Problem 3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (a)

# %% [markdown]
# ### (b)

# %% [markdown]
# ## Problem 5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 6
#
# ![image.png](attachment:image.png)
