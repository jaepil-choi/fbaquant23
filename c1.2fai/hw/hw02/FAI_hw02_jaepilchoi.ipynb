# %% [markdown]
# # FAI hw 02
#
# 최재필

# %% [markdown]
# ## Q1
#
# ![image.png](attachment:image.png)

# %%
from krx import WebSource
from binance import PublicData

# %% [markdown]
# ## Q2
#
# ![image.png](attachment:image.png)
