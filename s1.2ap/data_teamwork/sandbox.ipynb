# %% [markdown]
# # Sandbox for datawork.

# %%
import pandas as pd
import numpy as np

from pathlib import Path

# %%
CWD_PATH = Path('.').resolve()
DATA_PATH = CWD_PATH / 'data'
DATA_PATH
# Out:
# WindowsPath('E:/VSCodeProjects/fbaquant23/s1.2ap/data_teamwork/data')

# %%
price_df = pd.read_csv(
    DATA_PATH / 'price.csv'
)

# %%
price_df
# Out:
#          PERMNO     CUSIP Ticker       mDate  ClosePrice     RecDate Delist  \
# 0         10001  36720410   EGAS  1990-01-31      9.9375  1990-01-31      N
# 1         10001  36720410   EGAS  1990-02-28      9.8750  1990-02-28      N
# 2         10001  36720410   EGAS  1990-03-30      9.8750  1990-03-30      N
# 3         10001  36720410   EGAS  1990-04-30      9.8750  1990-04-30      N
# 4         10001  36720410   EGAS  1990-05-31      9.7500  1990-05-31      N
# ...         ...       ...    ...         ...         ...         ...    ...
# 3040852   93436  88160R10   TSLA  2022-08-31    275.6100  2022-08-31      N
# 3040853   93436  88160R10   TSLA  2022-09-30    265.2500  2022-09-30      N
# 3040854   93436  88160R10   TSLA  2022-10-31    227.5400  2022-10-31      N
# 3040855   93436  88160R10   TSLA  2022-11-30    194.7000  2022-11-30      N
# 3040856   93436  88160R10   TSLA  2022-12-30    123.1800  2022-12-30      N
#
# ...

# %%
len(price_df[['CUSIP', 'mDate']])
# Out:
# 3040857

# %%
len(set([(cusip, mDate) for cusip, mDate in price_df[['CUSIP', 'mDate']].values]))
# Out:
# 3012454

# %%
len(price_df[['PERMNO', 'mDate']])
# Out:
# 3040857

# %%
len(set([(permno, mDate) for permno, mDate in price_df[['PERMNO', 'mDate']].values]))
# Out:
# 3012454

# %%
header_df = pd.read_csv(
    DATA_PATH / 'header.csv'
)

# %%
header_df
# Out:
#        PERMNO       Start         End     CUSIP     CUSIP9 Exchange Class  \
# 0       78736  1997-08-05  1997-08-18  00002130  000021303        Q   NaN
# 1       25881  1970-11-13  1978-06-22  00003210  000032102        A   NaN
# 2       10015  1985-01-22  1986-07-08  00016510  000165100        Q   NaN
# 3       11307  1987-05-08  1993-10-14  00020910  000209106        Q   NaN
# 4       14945  2019-08-09  2019-10-25  00030710  000307108        N   NaN
# ...       ...         ...         ...       ...        ...      ...   ...
# 36969   14789  2016-08-01  2016-12-08  Y8977Y10  Y8977Y100        N   NaN
# 36970   23201  2022-07-08  2022-12-30  Y9233510  Y92335101        Q   NaN
# 36971   91372  2008-06-27  2011-07-01  Y9369110  Y93691106        Q   NaN
# 36972   14858  2016-08-01  2017-09-14  Y9384M10  Y9384M101        N   NaN
# 36973   15857  2015-12-25  2022-12-30  Y9530810  Y95308105        Q   NaN
#
#       Ticker                         Name
# ...

# %%
ratio_df = pd.read_csv(
    DATA_PATH / 'ratio.csv'
)

# %%
ratio_df
# Out:
#           gvkey  permno       adate       qdate public_date   CAPEI  \
# 0          1004   54594  1989-05-31  1989-11-30  1990-01-31  30.082
# 1          1004   54594  1989-05-31  1989-11-30  1990-02-28  29.724
# 2          1004   54594  1989-05-31  1989-11-30  1990-03-31  28.746
# 3          1004   54594  1989-05-31  1990-02-28  1990-04-30  19.616
# 4          1004   54594  1989-05-31  1990-02-28  1990-05-31  19.276
# ...         ...     ...         ...         ...         ...     ...
# 1856807  349972   15642  2021-12-31  2022-06-30  2022-08-31     NaN
# 1856808  349972   15642  2021-12-31  2022-06-30  2022-09-30     NaN
# 1856809  349972   15642  2021-12-31  2022-06-30  2022-10-31     NaN
# 1856810  349972   15642  2021-12-31  2022-09-30  2022-11-30     NaN
# 1856811  349972   15642  2021-12-31  2022-09-30  2022-12-31     NaN
#
#          BM (Book to Market)  EVEBITDA    POER  POER_dil  ...  INTCOV  ATURN  \
# ...
