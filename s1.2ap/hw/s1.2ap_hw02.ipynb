# %% [markdown]
# # HW02
#
# 최재필
#
# Assignment 3
#
# Solve the following problems

# %%
import pandas as pd
import numpy as np

from scipy.stats import norm

# %% [markdown]
# ## Problem 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 2
#
# ![image.png](attachment:image.png)

# %%
b = (2 - 0.3) / np.sqrt(1.8)
b
# Out:
# 1.2671051872498809

# %%
norm.cdf(b)
# Out:
# 0.8974411594832974

# %% [markdown]
# ## Problem 3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 4
#
# ![image.png](attachment:image.png)
