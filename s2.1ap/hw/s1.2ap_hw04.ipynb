# %% [markdown]
# # HW04
#
# 최재필
#
# https://nbviewer.org/github/jaepil-choi/fbaquant23/blob/master/s1.2ap/hw/s1.2ap_hw04.ipynb

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path
from tqdm import tqdm

# %%
import scipy
import statsmodels
import statsmodels.sandbox.distributions as smdist

# %%
np.random.seed(123)

# %%
BASE_PATH = Path('.').resolve().parents[0]
BASE_PATH
# Out:
# WindowsPath('E:/VSCodeProjects/fbaquant23/s1.2ap')

# %%
# data_path = Path(__file__).resolve() / 'data' # Interactive shell에선 안된다. 
data_path = Path('.').resolve() / 'data'
data_path
# Out:
# WindowsPath('E:/VSCodeProjects/fbaquant23/s1.2ap/hw/data')

# %%
coursera_data_path = BASE_PATH / 'coursera' / 'Introduction to Portfolio Construction and Analysis with Python' / 'data'
coursera_data_path
# Out:
# WindowsPath('E:/VSCodeProjects/fbaquant23/s1.2ap/coursera/Introduction to Portfolio Construction and Analysis with Python/data')

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ## Problem 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### hint

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (a)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (b)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (c)

# %% [markdown]
# ### (d)

# %% [markdown]
# ## Problem 4

# %% [markdown]
# ### (a)

# %% [markdown]
# ### (b)

# %% [markdown]
# ### (c)

# %% [markdown]
# ### (d)
