# %% [markdown]
# # HW05
#
# 최재필
#
# https://nbviewer.org/github/jaepil-choi/fbaquant23/blob/master/s1.2ap/hw/s1.2ap_hw05.ipynb

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path
from tqdm import tqdm

# %%
np.random.seed(123)

# %%
BASE_PATH = Path('.').resolve().parents[0]
BASE_PATH
# Out:
# WindowsPath('E:/VSCodeProjects/fbaquant23/s1.2ap')

# %%
# data_path = Path(__file__).resolve() / 'data' # Interactive shell에선 안된다. 
data_path = Path('.').resolve() / 'data'
data_path
# Out:
# WindowsPath('E:/VSCodeProjects/fbaquant23/s1.2ap/hw/data')

# %%
coursera_data_path = BASE_PATH / 'coursera' / 'Introduction to Portfolio Construction and Analysis with Python' / 'data'
coursera_data_path
# Out:
# WindowsPath('E:/VSCodeProjects/fbaquant23/s1.2ap/coursera/Introduction to Portfolio Construction and Analysis with Python/data')

# %% [markdown]
# ## Problem 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (a)
#
# 1) Using the Lagrange Multiplier Methods, Find the optimal weights of portfolio under given the target expected return μ_0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (b)
#
# 2) Find the weight vector of the Tangency Portfolio.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (c)
#
# 3) Find the variance of the optimal portfolio.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (d)
#
# 4) Use the risk-aversion parameter to indicate the weight of the optimal portfolio. (Definition of risk aversion parameter  $ \lambda = \frac{\mu - r_{f}}{\sigma^2} $ )

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (e)
#
# 5) Show that under a given constraint, all optimal portfolios have the same Sharpe Ratio and that all optimal portfolios are above the CAL of the Tangency portfolio.

# %% [markdown]
# ## Problem 3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (a)

# %% [markdown]
# ### (b)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 5
#
# ![image.png](attachment:image.png)
